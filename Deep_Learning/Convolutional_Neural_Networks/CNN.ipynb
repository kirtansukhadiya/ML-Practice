# %% [markdown]
# Convolutional Neural Network

# %% [markdown]
# Importing Libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.20.0'

# %% [markdown]
# Part 1 Data Preprocessing
# Preprocessing with the training set

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range= 0.2,
    zoom_range=0.2,
    horizontal_flip=True)
training_set = train_datagen.flow_from_directory(
    'dataset/training_set',
    target_size=(64,64),
    batch_size= 32,
    class_mode='binary'
)
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# Preprocessing with test set

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_set = test_datagen.flow_from_directory(
    'dataset/test_set',
    target_size=(64,64),
    batch_size= 32,
    class_mode='binary'
)
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# Part 2 Building the CNN
# Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3, activation='relu', input_shape=[64,64,3]))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units = 128, activation = 'relu'))

# %% [markdown]
# Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# %% [markdown]
# Part 3 Training the CNN
# Compiling the CNN

# %%
cnn.compile(optimizer='adam', loss= 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# Training the CNN on the training set and evaluating it on the test set

# %%
cnn.fit(x = training_set, validation_data= test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 41ms/step - accuracy: 0.5957 - loss: 0.6688 - val_accuracy: 0.6625 - val_loss: 0.6190
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.6678 - loss: 0.6078 - val_accuracy: 0.7090 - val_loss: 0.5724
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.7091 - loss: 0.5582 - val_accuracy: 0.7415 - val_loss: 0.5290
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 50ms/step - accuracy: 0.7368 - loss: 0.5236 - val_accuracy: 0.7445 - val_loss: 0.5154
# Epoch 5/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 13s 51ms/step - accuracy: 0.7554 - loss: 0.4994 - val_accuracy: 0.7645 - val_loss: 0.4927
# Epoch 6/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 44ms/step - accuracy: 0.7685 - loss: 0.4759 - val_accuracy: 0.7820 - val_loss: 0.4801
# Epoch 7/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.7761 - loss: 0.4610 - val_accuracy: 0.7775 - val_loss: 0.4743
# Epoch 8/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.7916 - loss: 0.4444 - val_accuracy: 0.7995 - val_loss: 0.4529
# Epoch 9/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.7975 - loss: 0.4295 - val_accuracy: 0.7910 - val_loss: 0.4504
# Epoch 10/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - accuracy: 0.8092 - loss: 0.4157 - val_accuracy: 0.7865 - val_loss: 0.4547
# Epoch 11/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.8186 - loss: 0.3959 - val_accuracy: 0.7970 - val_loss: 0.4583
# Epoch 12/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 42ms/step - accuracy: 0.8235 - loss: 0.3922 - val_accuracy: 0.7870 - val_loss: 0.4519
# Epoch 13/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 43ms/step - accuracy: 0.8344 - loss: 0.3701 - val_accuracy: 0.8080 - val_loss: 0.4381
# Epoch 14/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 41ms/step - accuracy: 0.8376 - loss: 0.3618 - val_accuracy: 0.7890 - val_loss: 0.4832
# Epoch 15/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.8400 - loss: 0.3476 - val_accuracy: 0.7910 - val_loss: 0.4577
# Epoch 16/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 40ms/step - accuracy: 0.8499 - loss: 0.3339 - val_accuracy: 0.8120 - val_loss: 0.4470
# Epoch 17/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 45ms/step - accuracy: 0.8530 - loss: 0.3235 - val_accuracy: 0.8015 - val_loss: 0.4618
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 44ms/step - accuracy: 0.8665 - loss: 0.3071 - val_accuracy: 0.7990 - val_loss: 0.4689
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 42ms/step - accuracy: 0.8676 - loss: 0.2969 - val_accuracy: 0.8035 - val_loss: 0.4889
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.8813 - loss: 0.2763 - val_accuracy: 0.8080 - val_loss: 0.4943
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.8852 - loss: 0.2654 - val_accuracy: 0.7860 - val_loss: 0.5616
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.8938 - loss: 0.2571 - val_accuracy: 0.8045 - val_loss: 0.4897
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.8990 - loss: 0.2458 - val_accuracy: 0.7925 - val_loss: 0.4977
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 9s 37ms/step - accuracy: 0.9010 - loss: 0.2372 - val_accuracy: 0.8035 - val_loss: 0.5371
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 10s 38ms/step - accuracy: 0.9125 - loss: 0.2197 - val_accuracy: 0.7995 - val_loss: 0.5481

# %% [markdown]
# Part 4 - Making a single prediction

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
test_image = image.load_img('dataset/Single_prediction/Cat-on-couch.jpg', target_size=(64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
else:
    prediction = 'cat'

print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# cat
